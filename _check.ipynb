# %%
from obspy.clients.filesystem.sds import Client
from obspy import UTCDateTime, read

# %%
client = Client(sds_root=r"D:\Data\OJN\OJN")

# %%
stream = client.get_waveforms(
    station="OJN",
    channel="EHN",
    network="VG",
    location="00",
    starttime=UTCDateTime("2025-01-01"),
    endtime=UTCDateTime("2025-01-03"),
)

# %%
stream
# Out:
# 0 Trace(s) in Stream:

# %%
st = read(r"D:\Data\OJN\OJN\2024\EHN.D\VG.OJN.00.EHN.D.2024.001")

# %%
st[0].stats
# Out:
#          network: VG
#          station: OJN
#         location: 00
#          channel: EHN
#        starttime: 2024-01-01T00:00:00.000000Z
#          endtime: 2024-01-01T23:59:59.000000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 8639901
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'dataquality': 'D', 'number_of_records': 1555, 'encoding': 'STEIM2', 'byteorder': '>', 'record_length': 4096, 'filesize': 6369280})
