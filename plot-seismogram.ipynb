# %%
from obspy import read
import glob

# %%
files = glob.glob(r"D:\Data\STRL\2025\VG\STRL\EHZ.D\*")

# %%
for file in files:
    st = read(file, headonly=True)
    print(st[0].stats)
    break
# Out:
#          network: VG
#          station: STRL
#         location: 00
#          channel: EHZ
#        starttime: 2025-12-10T23:36:45.000000Z
#          endtime: 2025-12-11T00:00:01.210000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 139622
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'dataquality': 'D', 'number_of_records': 952, 'encoding': 'STEIM2', 'byteorder': '>', 'record_length': 512, 'filesize': 487424})
