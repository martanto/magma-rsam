# %%
from magma_database import RsamCSV
from datetime import datetime,timezone

# %%
_rsam, exists = RsamCSV.get_or_create(
    key="VG.OJN.00.EHN_2025-01-01_10min_5.0_16.0",
    date="2025-01-01",
    defaults={
        "nslc": "VG.OJN.00.EHN",
        "resample": "10min",
        "freq_min": 5.0,
        "freq_max": 16.0,
        "file_location": r"D:\Projects\magma-rsam\output\rsam\VG.OJN.00.EHN\filtered_5.0_16.0\10min\2025-01-01.csv",
        "created_at": datetime.now(tz=timezone.utc),
    },
)

# %%
_rsam, exists
# Out:
# (<RsamCSV: 1080>, False)

# %%
if exists:
    print( _rsam.get_id())

# %%
_rsam.key = "VG.OJN.00.EHN_2025-01-01_10min_5.0_16.0"
_rsam.nslc = "VG.OJN.00.EHN"
_rsam.date = "2025-01-01"
_rsam.resample = "10min"
_rsam.freq_min = 5.0
_rsam.freq_max = 16.0
_rsam.file_location = r"D:\Projects\magma-rsam\output\rsam\VG.OJN.00.EHN\filtered_5.0_16.0\10min\2025-01-01.csv"
_rsam.updated_at = datetime.now(tz=timezone.utc)

# %%
_rsam.save()
# Out:
# 1

# %%
_rsam.key
# Out:
# 'VG.OJN.00.EHN_2025-01-01_10min_5.0_16.0'
