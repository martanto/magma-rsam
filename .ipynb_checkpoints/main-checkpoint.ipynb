# %%
from magma_rsam import RSAM, PlotRsam
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime
import pandas as pd

# %%
start_date='2022-10-01'
end_date='2022-12-31'
station="LEKR"
channel="EHZ"

# %%
freq_min = 1.0
freq_max = 5.0

# %%
rsam = RSAM(
    seismic_dir="Y:\\Converted\\SDS",
    station=station,
    channel=channel,
    start_date=start_date,
    end_date=end_date,
)

# %%
rsam.apply_filter(freq_min=freq_min, freq_max=freq_max)
# Out:
# ℹ️ Filter is on.

# %%
rsam.run()
# Out:
# ✅ 2022-10-01 :: File RSAM for VG.LEKR.00.EHZ : D:\Project\magma-rsam\output\rsam\VG.LEKR.00.EHZ\filtered_1.0_5.0\10min\2022-10-01.csv
# ⚠️ 2022-10-02 :: Skip. No traces found
# ✅ 2022-10-03 :: File RSAM for VG.LEKR.00.EHZ : D:\Project\magma-rsam\output\rsam\VG.LEKR.00.EHZ\filtered_1.0_5.0\10min\2022-10-03.csv
# ✅ 2022-10-04 :: File RSAM for VG.LEKR.00.EHZ : D:\Project\magma-rsam\output\rsam\VG.LEKR.00.EHZ\filtered_1.0_5.0\10min\2022-10-04.csv
# ✅ 2022-10-05 :: File RSAM for VG.LEKR.00.EHZ : D:\Project\magma-rsam\output\rsam\VG.LEKR.00.EHZ\filtered_1.0_5.0\10min\2022-10-05.csv
# 🔄️ Apply filter
# ⌚ 2022-10-06 Calculating for VG.LEKR.00.EHZ
# 💾 Saved to D:\Project\magma-rsam\output\rsam\VG.LEKR.00.EHZ\filtered_1.0_5.0\10min\2022-10-06.csv
# 🔄️ Apply filter
# ⌚ 2022-10-07 Calculating for VG.LEKR.00.EHZ
# 💾 Saved to D:\Project\magma-rsam\output\rsam\VG.LEKR.00.EHZ\filtered_1.0_5.0\10min\2022-10-07.csv
# 🔄️ Apply filter
# ⌚ 2022-10-08 Calculating for VG.LEKR.00.EHZ
# ...

# %%
plot_rsam = PlotRsam(
    station=station,
    channel=channel,
    start_date=start_date,
    end_date=end_date,
)
# Out:
# ℹ️ Start Date: 2022-10-01
# ℹ️ End Date: 2022-12-31
# ℹ️ Station: LEKR
# ℹ️ Channel: EHZ
# ℹ️ Network: VG
# ℹ️ Location: 00
# ℹ️ Resample: 10min

# %%
plot_rsam.with_filter(freq_min=freq_min, freq_max=freq_max)

# %%
plot_rsam.filtered_dir
# Out:
# 'D:\\Project\\magma-rsam\\output\\rsam\\VG.LEKR.00.EHZ\\filtered_1.0_5.0'

# %%
plot_rsam.set_y_lim(y_min=0, y_max=200).run(
    datetime_interval=7,
)
# Out:
# ✅ Combined CSV saved to : D:\Project\magma-rsam\output\rsam\VG.LEKR.00.EHZ\filtered_1.0_5.0\combined_VG.LEKR.00.EHZ_2022-10-01-2022-12-31_1.0-5.0Hz_10min.csv
# ⬆️ Max Amplitude: 15467.798636095013
# ⬇️ Min Amplitude: 1.4908239200537013e-08
# 📈 RSAM Figure saved to : D:\Project\magma-rsam\output\figures\rsam\VG.LEKR.00.EHZ_2022-10-01-2022-12-31_1.0-5.0Hz_10min.png
#                           min         mean            max       median  \
# datetime
# 2022-10-01 00:00:00  0.283503  5185.886080  134465.735072  2846.587386
# 2022-10-01 00:10:00  0.000210   550.538786   12895.864595     0.003289
# 2022-10-01 00:20:00  0.003289     0.003289       0.003289     0.003289
# 2022-10-01 00:30:00  0.003289     0.003289       0.003289     0.003289
# 2022-10-01 00:40:00  0.003289     0.003289       0.003289     0.003289
# ...                       ...          ...            ...          ...
# 2022-12-31 23:10:00  0.000536    24.797677    1055.134269     6.655771
# ...

# %%
df_low_freq = pd.read_csv(r'D:\Project\magma-rsam\output\rsam\VG.LEKR.00.EHZ\filtered_0.1_1.0\combined_VG.LEKR.00.EHZ_2021-10-01-2021-12-31_0.1-1.0Hz_10min.csv', parse_dates=True)
df_med_freq = pd.read_csv(r'D:\Project\magma-rsam\output\rsam\VG.LEKR.00.EHZ\filtered_1.0_5.0\combined_VG.LEKR.00.EHZ_2021-10-01-2021-12-31_1.0-5.0Hz_10min.csv', parse_dates=True)
df_high_freq = pd.read_csv(r'D:\Project\magma-rsam\output\rsam\VG.LEKR.00.EHZ\filtered_5.0_18.0\combined_VG.LEKR.00.EHZ_2021-10-01-2021-12-31_5.0-18.0Hz_10min.csv')

# %%
df_med_freq
# Out:
#                   datetime           min       mean          max     median  \
# 0      2021-10-01 00:00:00  1.775430e-06   9.329246   824.689720   6.288883
# 1      2021-10-01 00:10:00  1.767295e-06   3.633340    94.359154   0.041731
# 2      2021-10-01 00:20:00  7.946857e-04  37.335939  1525.673102  13.891836
# 3      2021-10-01 00:30:00  8.618939e-06   9.265401   178.695517   7.058994
# 4      2021-10-01 00:40:00  6.444381e-05  14.344242   387.364080   6.712994
# ...                    ...           ...        ...          ...        ...
# 10356  2021-12-31 23:10:00  1.045338e-04   4.094166    28.705673   3.406977
# 10357  2021-12-31 23:20:00  9.996809e-05   5.874845    65.507668   4.332791
# 10358  2021-12-31 23:30:00  3.207731e-04   5.282799    38.386905   4.038885
# 10359  2021-12-31 23:40:00  5.995980e-05   5.440974    83.727541   3.920101
# 10360  2021-12-31 23:50:00  4.976970e-07   5.110032    66.470619   4.011900
#
#               std
# 0       18.056066
# ...

# %%
df_stack = (pd.concat([df_low_freq,df_low_freq, df_high_freq],axis=0)).groupby('datetime')[['median', 'mean']].sum().reset_index()

# %%
df_stack.set_index('datetime', inplace=True)

# %%
df_stack.index = pd.to_datetime(df_stack.index)

# %%
df_stack['mean_24h'] = df_stack['mean'].rolling('24h', center=True).median()
df_stack['median_24h'] = df_stack['median'].rolling('24h', center=True).median()

# %%
df_stack.to_csv('df_stack_2022.csv')

# %%
fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(12, 4),
                        layout="constrained", sharex=True)

axs.scatter(df_stack.index, df_stack['median'], c='k', alpha=0.2, s=3, label='10 minutes median')
axs.plot(df_stack.index, df_stack['mean_24h'], c='red', label='mean 1d', alpha=1, lw=2)
axs.plot(df_stack.index, df_stack['median_24h'], c='yellow', label='median 1d', alpha=1, lw=2)
axs.set_ylabel('Amplitude Stacked (count)')

axs.set_ylim(-5, 100)

axs.legend(loc='upper left', fontsize='10', ncol=4)

axs.axvline(datetime.strptime("2021-12-07", '%Y-%m-%d'),
            color='orange', label='First Eruption')

for label in axs.get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')

# %%
# df = plot_rsam.df

# %%
# datetime_index: pd.DatetimeIndex = pd.date_range(start=start_date, end=end_date, freq='10min')

# %%
# df = df.reindex(datetime_index)

# %%
# df['mean_24h'] = df['mean'].rolling('24h', center=True).median()

# %%
# fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(12, 4),
#                         layout="constrained", sharex=True)
# 
# axs.scatter(df.index, df['mean'], c='k', alpha=0.2, s=3, label='10 minutes')
# axs.plot(df.index, df['mean_24h'], c='red', label='median 1d', alpha=1, lw=2)
# axs.set_ylabel('Amplitude (count)')
# 
# axs.xaxis.set_major_locator(mdates.DayLocator(interval=7))
# axs.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
# axs.set_ylim(-150, 15000)
# # axs.set_yscale('log')
# axs.set_xlim(datetime.strptime(start_date, '%Y-%m-%d'), datetime.strptime(end_date, '%Y-%m-%d'))
# 
# # axs.axvspan("2024-04-16", "2024-04-19", alpha=0.2,
# #              color='orange', label='Continuous Eruption')
# # 
# # axs.axvline(datetime.strptime("2024-04-16", '%Y-%m-%d'),
# #             color='red', label='First Eruption')
# 
# for label in axs.get_xticklabels(which='major'):
#     label.set(rotation=30, horizontalalignment='right')
#     
# axs.legend(loc='upper left', fontsize='10', ncol=4)
# 
# fig.savefig(f"rsam_awu_{station}_not_filtered.png")
# # fig.savefig(f'rsam_awu_{station}_filtered_5-18Hz.png')

# %%
# continuous_events = [
#     {
#         'name': 'Eruption',
#         'dates': ['2024-04-16', '2024-04-16'],
#         'color': 'orange'
#     }
# ]

# %%
# events = [
#     {
#         'name': 'Level II',
#         'dates': ['2024-04-16', '2024-04-18'],
#         'color': 'orange'
#     }
# ]

# %%
# continuous_events = continuous_events + events

# %%
# continuous_events
